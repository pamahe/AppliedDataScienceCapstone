# %%
import numpy as npf
import pandas as pd
import geopandas as gpd

# %%
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)

# %% [markdown]
# # Green Spaces Dataset Wrangling

# %%
fname = "./Data/espacesVerts.geojson"
grass_gdf = gpd.read_file(fname)

# %%
grass_gdf.head()
# Out:
#            gml_id                    nom        surf_nat      numero  \
# 0  gev_senh.64928  MAIL LOUISE BOURGEOIS         PELOUSE  0972SENH01
# 1  gev_senh.64929    CHEMIN DES LOUVRIES         PRAIRIE  1362SENH02
# 2  gev_senh.64930    CHEMIN DES LOUVRIES         PRAIRIE  1362SENH01
# 3  gev_senh.64931  MAIL LOUISE BOURGEOIS  PRAIRIE HUMIDE  0972SENH11
# 4  gev_senh.64932  MAIL LOUISE BOURGEOIS         PELOUSE  0972SENH04
#
#             nom_voie numsite  nuquart  nusect  objectid  id_senh materiel  \
# 0       Saint-Hélier    0972      8.0    19.0     64928      NaN     None
# 1  des Iles Chaussey    1362      5.0    14.0     64929      NaN     None
# 2  des Iles Chaussey    1362      5.0    14.0     64930      NaN     None
# 3       Saint-Hélier    0972      8.0    19.0     64931      NaN     None
# 4       Saint-Hélier    0972      8.0    19.0     64932      NaN     None
#
#                                             geometry
# 0  MULTIPOLYGON (((-1.66297 48.10281, -1.66295 48...
# 1  MULTIPOLYGON (((-1.62954 48.14565, -1.62954 48...
# 2  MULTIPOLYGON (((-1.63062 48.14727, -1.63063 48...
# 3  MULTIPOLYGON (((-1.66363 48.10279, -1.66367 48...
# 4  MULTIPOLYGON (((-1.66313 48.10266, -1.66300 48...

# %% [markdown]
# We only need a few informations:
#     - the name of the place
#     - the type
#     - the neighborhood ID
#     - and the geometry

# %%
grass_gdf.drop(['gml_id', 'numero', 'nom_voie', 'numsite', 'nuquart', 'objectid', 'id_senh', 'materiel'], axis=1, inplace=True)

# %%
# This is the Neighborhood_ID
grass_gdf['nusect'].unique()
# Out:
# array([19., 14., 18., 13., 10., 38., 36., 29.,  9., 11., 42.,  1., 25.,
#        17., 33., 16., 28., 12., 24., 35., 26.,  4., 22., 21., 34., 15.,
#        39.,  6., 27., 30.,  5.,  8., nan])

# %%
for index, row in grass_gdf.iterrows():
    if row['nusect'] != row['nusect']:
        print(row)
# Out:
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.695644759804986 48.1310227430573...
# Name: 11862, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.696365864615534 48.1310983453010...
# Name: 11863, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.696723202092756 48.1312662209487...
# Name: 11864, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.696904148651216 48.1312993865902...
# Name: 11865, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.696933591244401 48.1312500817493...
# Name: 11866, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.697942899759791 48.1314570771003...
# Name: 11867, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.697937377714446 48.1314297925061...
# Name: 11868, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.698832170144422 48.1316148555627...
# Name: 11869, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.698926002414905 48.1316556235039...
# Name: 11870, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.698954374413424 48.1316103482180...
# Name: 11871, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.700348276569361 48.1318578572094...
# Name: 11872, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.701235702812782 48.1320414803571...
# Name: 11873, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.701372889759972 48.1320861170741...
# Name: 11874, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.7014001196978 48.13204380731356,...
# Name: 11875, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.70228596680636 48.13224785448067...
# Name: 11876, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.702443042005697 48.1322755195408...
# Name: 11877, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.702476830172535 48.1322162955854...
# Name: 11878, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.703499271491012 48.1323271456141...
# Name: 11879, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.701712112753654 48.1319671174689...
# Name: 11880, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.700047813124173 48.1316712883319...
# Name: 11881, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.698922073296681 48.1315147550763...
# Name: 11882, dtype: object
# nom                                                      None
# surf_nat                                                 None
# nusect                                                    NaN
# geometry    (POLYGON ((-1.697934727018605 48.1313391651003...
# Name: 11883, dtype: object

# %% [markdown]
# We are not dropping the NaN value just yet as we may be able to localize it based on the geometry anyway

# %%
grass_gdf.rename(columns={'nom':'Name', 'surf_nat':'Type of Surface', 'nusect':'Neighborhood_ID'}, inplace=True)
grass_gdf.head()
# Out:
#                     Name Type of Surface  Neighborhood_ID  \
# 0  MAIL LOUISE BOURGEOIS         PELOUSE             19.0
# 1    CHEMIN DES LOUVRIES         PRAIRIE             14.0
# 2    CHEMIN DES LOUVRIES         PRAIRIE             14.0
# 3  MAIL LOUISE BOURGEOIS  PRAIRIE HUMIDE             19.0
# 4  MAIL LOUISE BOURGEOIS         PELOUSE             19.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-1.66297 48.10281, -1.66295 48...
# 1  MULTIPOLYGON (((-1.62954 48.14565, -1.62954 48...
# 2  MULTIPOLYGON (((-1.63062 48.14727, -1.63063 48...
# 3  MULTIPOLYGON (((-1.66363 48.10279, -1.66367 48...
# 4  MULTIPOLYGON (((-1.66313 48.10266, -1.66300 48...

# %%
grass_gdf
# Out:
#                          Name Type of Surface  Neighborhood_ID  \
# 0       MAIL LOUISE BOURGEOIS         PELOUSE             19.0
# 1         CHEMIN DES LOUVRIES         PRAIRIE             14.0
# 2         CHEMIN DES LOUVRIES         PRAIRIE             14.0
# 3       MAIL LOUISE BOURGEOIS  PRAIRIE HUMIDE             19.0
# 4       MAIL LOUISE BOURGEOIS         PELOUSE             19.0
# ...                       ...             ...              ...
# 11907  SQUARE DU GRAND PLACIS         PELOUSE             36.0
# 11908  SQUARE DU GRAND PLACIS         PELOUSE             36.0
# 11909  SQUARE DU GRAND PLACIS         PELOUSE             36.0
# 11910       RUE EMILE BERNARD         PELOUSE             36.0
# 11911       RUE EMILE BERNARD         PELOUSE             36.0
#
#                                                 geometry
# 0      MULTIPOLYGON (((-1.66297 48.10281, -1.66295 48...
# 1      MULTIPOLYGON (((-1.62954 48.14565, -1.62954 48...
# 2      MULTIPOLYGON (((-1.63062 48.14727, -1.63063 48...
# 3      MULTIPOLYGON (((-1.66363 48.10279, -1.66367 48...
# 4      MULTIPOLYGON (((-1.66313 48.10266, -1.66300 48...
# ...                                                  ...
# 11907  MULTIPOLYGON (((-1.66140 48.13922, -1.66141 48...
# 11908  MULTIPOLYGON (((-1.66035 48.14065, -1.66040 48...
# 11909  MULTIPOLYGON (((-1.66079 48.13953, -1.66077 48...
# 11910  MULTIPOLYGON (((-1.66740 48.13968, -1.66740 48...
# 11911  MULTIPOLYGON (((-1.66517 48.13813, -1.66522 48...
#
# [11912 rows x 4 columns]

# %%
grass_gdf['Type of Surface'].unique()
# Out:
# array(['PELOUSE', 'PRAIRIE', 'PRAIRIE HUMIDE', 'PRAIRIE FLEURIE',
#        'FLEURISSEMENT EXTENSIF BULBE', 'DALLAGE JOINT GAZON',
#        'PRAIRIE DE FAUCHE', 'PRAIRIE RUSTIQUE', 'DALLE ALVEOLEE',
#        'EVERGREEN', 'PRAIRIE SECHE', None], dtype=object)

# %%
# Translating 'Type of Surface' column
# NB : I took some liberty for the translation as I don't have extensive info 
# on the meaning of each category
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PELOUSE'), 'Type of Surface'] = 'Grass'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PRAIRIE'), 'Type of Surface'] = 'Meadow'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PRAIRIE HUMIDE'), 'Type of Surface'] = 'Wet Meadow'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PRAIRIE FLEURIE'), 'Type of Surface'] = 'Flowery Meadow'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'FLEURISSEMENT EXTENSIF BULBE'), 'Type of Surface'] = 'Extensive Flowering'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'DALLAGE JOINT GAZON'), 'Type of Surface'] = 'Grass-Covered joints'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PRAIRIE DE FAUCHE'), 'Type of Surface'] = 'Hay field'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PRAIRIE RUSTIQUE'), 'Type of Surface'] = 'Hardy Meadow'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'DALLE ALVEOLEE'), 'Type of Surface'] = 'Hollow-Core Slab'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'EVERGREEN'), 'Type of Surface'] = 'Evergreen'
grass_gdf.loc[(grass_gdf['Type of Surface'] == 'PRAIRIE SECHE'), 'Type of Surface'] = 'Dry Meadow'

# %%
grass_gdf['Latitude'] = grass_gdf['geometry'].centroid.y
grass_gdf['Longitude'] = grass_gdf['geometry'].centroid.x

# %%
grass_gdf.dropna(subset=['Neighborhood_ID'], axis=0, inplace=True)
grass_gdf['Neighborhood_ID'] = grass_gdf['Neighborhood_ID'].astype('int')

# %%
fixed_columns = ['Name', 'Neighborhood_ID', 'Type of Surface', 'Latitude', 'Longitude', 'geometry']
grass_gdf = grass_gdf[fixed_columns]

# %%
grass_gdf
# Out:
#                          Name  Neighborhood_ID Type of Surface   Latitude  \
# 0       MAIL LOUISE BOURGEOIS               19           Grass  48.102762
# 1         CHEMIN DES LOUVRIES               14          Meadow  48.146857
# 2         CHEMIN DES LOUVRIES               14          Meadow  48.146189
# 3       MAIL LOUISE BOURGEOIS               19      Wet Meadow  48.102745
# 4       MAIL LOUISE BOURGEOIS               19           Grass  48.102661
# ...                       ...              ...             ...        ...
# 11907  SQUARE DU GRAND PLACIS               36           Grass  48.139286
# 11908  SQUARE DU GRAND PLACIS               36           Grass  48.140683
# 11909  SQUARE DU GRAND PLACIS               36           Grass  48.139516
# 11910       RUE EMILE BERNARD               36           Grass  48.139718
# 11911       RUE EMILE BERNARD               36           Grass  48.138149
#
#        Longitude                                           geometry
# 0      -1.662893  MULTIPOLYGON (((-1.66297 48.10281, -1.66295 48...
# 1      -1.630007  MULTIPOLYGON (((-1.62954 48.14565, -1.62954 48...
# 2      -1.630393  MULTIPOLYGON (((-1.63062 48.14727, -1.63063 48...
# 3      -1.663677  MULTIPOLYGON (((-1.66363 48.10279, -1.66367 48...
# 4      -1.663064  MULTIPOLYGON (((-1.66313 48.10266, -1.66300 48...
# ...          ...                                                ...
# 11907  -1.661406  MULTIPOLYGON (((-1.66140 48.13922, -1.66141 48...
# 11908  -1.660336  MULTIPOLYGON (((-1.66035 48.14065, -1.66040 48...
# 11909  -1.660742  MULTIPOLYGON (((-1.66079 48.13953, -1.66077 48...
# 11910  -1.667388  MULTIPOLYGON (((-1.66740 48.13968, -1.66740 48...
# 11911  -1.665239  MULTIPOLYGON (((-1.66517 48.13813, -1.66522 48...
#
# [11890 rows x 6 columns]

# %%
grass_gdf.to_file("./Data/cleaned_data/grasslands.geojson", driver='GeoJSON')
